# %% [markdown]
# <a href="https://colab.research.google.com/github/FREYDER18/SYS/blob/main/ARCHIVO_ENTRNADO_D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#cargar datos desde drive acceso libre

FILEID = "1VFH_1ooMRZNn4Vt1chhyqv4UU52H_JD-"



# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O  canciones.xlsx && rm -rf /tmp/cookies.txt
# Out:
# --2025-06-16 03:26:33--  https://docs.google.com/uc?export=download&confirm=&id=1VFH_1ooMRZNn4Vt1chhyqv4UU52H_JD-
# Resolving docs.google.com (docs.google.com)... 142.251.184.113, 142.251.184.100, 142.251.184.138, ...
# Connecting to docs.google.com (docs.google.com)|142.251.184.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1VFH_1ooMRZNn4Vt1chhyqv4UU52H_JD-&export=download [following]
# --2025-06-16 03:26:33--  https://drive.usercontent.google.com/download?id=1VFH_1ooMRZNn4Vt1chhyqv4UU52H_JD-&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 209.85.145.132, 2607:f8b0:4001:c1e::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|209.85.145.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9730 (9.5K) [application/octet-stream]
# Saving to: ‘canciones.xlsx’
#
# canciones.xlsx      100%[===================>]   9.50K  --.-KB/s    in 0s
#
# 2025-06-16 03:26:35 (56.4 MB/s) - ‘canciones.xlsx’ saved [9730/9730]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_ = 'canciones.xlsx'#leer archivo xlsx con link, band, type
X  = pd.read_excel(file_)
X#imprimir filas iniciales
# Out:
#                                  link            band     type  type_num
# 0   https://youtu.be/DXiXPhvYuNU?t=13    romeo santos  bachata         1
# 1   https://youtu.be/0XCot42qTvA?t=23        aventura  bachata         1
# 2    https://youtu.be/mhHqonzsuoA?t=4    romeo santos  bachata         1
# 3    https://youtu.be/ABjGqQgXRBo?t=3    romeo santos  bachata         1
# 4   https://youtu.be/2p_eRTj5s5M?t=25    romeo santos  bachata         1
# 5    https://youtu.be/RjMWh1vve6E?t=2    romeo santos  bachata         1
# 6    https://youtu.be/4B7OGEy3Zgc?t=4           royce  bachata         1
# 7    https://youtu.be/8x7adVOw9G8?t=2    romeo santos  bachata         1
# 8    https://youtu.be/dZYJ1yQlsY8?t=2     david pabon    salsa         2
# 9    https://youtu.be/dH7bTCsNlNo?t=2   jerry rivera     salsa         2
# 10   https://youtu.be/T63FtnrUDEo?t=3     maelo ruiz     salsa         2
# 11   https://youtu.be/-g-3ptRfFP4?t=4    grupo niche     salsa         2
# 12  https://youtu.be/knlWR9mhkBs?t=11  roberto roena     salsa         2
# 13   https://youtu.be/dMmPQ_Wi_Hs?t=3  polo montanez     salsa         2
# 14   https://youtu.be/X4jDz0A1Fc0?t=4   marc anthony     salsa         2
# 15   https://youtu.be/Jca2-CCcVXk?t=4   jerry rivera     salsa         2

# %%
#instalar librerias necesarias para descargar audios youtube
# !python3 -m pip install --force-reinstall https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
# !pip install soundfile

# Paquete de carga de cookies para el control anti-bots captcha
# !pip install browser-cookie3

import os
import yt_dlp as youtube_dl
import browser_cookie3

try:
    cookies = browser_cookie3.firefox()
except:
    print("No se pueden descargar cookies desde firefox. Intentando Chrome...")
    try:
        cookies = browser_cookie3.chrome()
    except:
        print("No se pueden descargar cookies desde Chrome. Por favor asegúrate de estar logueado en Youtube desde tu navegador.")
        cookies = None

#funcion para descargar mp3 desde youtube
def download_ytvid_as_mp3(video_url,name):
    #video_url = input("enter url of youtube video:")
    options={
        'format':'bestaudio/best',
        'keepvideo':False,
        'outtmpl':f'{name}.mp3',
    }
    if cookies:
        options['cookiefile'] = None
        options['cookiejar'] = cookies;

    with youtube_dl.YoutubeDL(options) as ydl:
        try:
            video_info = ydl.extract_info(video_url, download=False)
            ydl.download([video_info['webpage_url']])
            print("Download complete... {}".format(filename))
        except Exception as e:
            print(f"Error descargando {video_url}: {e}")
# Out:
# Collecting https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
#   Downloading https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 12.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: yt-dlp
#   Building wheel for yt-dlp (pyproject.toml) ... done
#   Created wheel for yt-dlp: filename=yt_dlp-2025.6.9-py3-none-any.whl size=3017173 sha256=f36fbc53d54ba3cc0439ef04f4607233803435989a5e123e6e60d330e75b3cb1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3a4j9npc/wheels/2d/79/97/7209650ef73114e0fe0603480da012ad3afacb9cae6b8acd9a
# Successfully built yt-dlp
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.6.9
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from soundfile) (2.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Collecting browser-cookie3
#   Downloading browser_cookie3-0.20.1-py3-none-any.whl.metadata (713 bytes)
# Collecting lz4 (from browser-cookie3)
#   Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.11/dist-packages (from browser-cookie3) (3.23.0)
# Requirement already satisfied: jeepney in /usr/local/lib/python3.11/dist-packages (from browser-cookie3) (0.9.0)
# Downloading browser_cookie3-0.20.1-py3-none-any.whl (17 kB)
# Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.8 MB/s eta 0:00:00
# Installing collected packages: lz4, browser-cookie3
# Successfully installed browser-cookie3-0.20.1 lz4-4.4.4
# No se pueden descargar cookies desde firefox. Intentando Chrome...
# No se pueden descargar cookies desde Chrome. Por favor asegúrate de estar logueado en Youtube desde tu navegador.

# %%
#instalar librerias necesarias para descargar audios youtube
# !python3 -m pip install --force-reinstall https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
# !pip install soundfile

# Paquete de carga de cookies para el control anti-bots captcha
# !pip install browser-cookie3

import os
import yt_dlp as youtube_dl
import browser_cookie3

try:
    cookies = browser_cookie3.firefox()
except:
    print("No se pueden descargar cookies desde firefox. Intentando Chrome...")
    try:
        cookies = browser_cookie3.chrome()
    except:
        print("No se pueden descargar cookies desde Chrome. Por favor asegúrate de estar logueado en Youtube desde tu navegador.")
        cookies = None

#funcion para descargar mp3 desde youtube
def download_ytvid_as_mp3(video_url,name):
    #video_url = input("enter url of youtube video:")
    options={
        'format':'bestaudio/best',
        'keepvideo':False,
        'outtmpl':f'{name}.mp3',
    }
    if cookies:
        options['cookiefile'] = None
        options['cookiejar'] = cookies;

    with youtube_dl.YoutubeDL(options) as ydl:
        try:
            video_info = ydl.extract_info(video_url, download=False)
            ydl.download([video_info['webpage_url']])
            print("Download complete... {}".format(filename))
        except Exception as e:
            print(f"Error descargando {video_url}: {e}")
# Out:
# Collecting https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
#   Using cached https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz (2.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: yt-dlp
#   Building wheel for yt-dlp (pyproject.toml) ... done
#   Created wheel for yt-dlp: filename=yt_dlp-2025.6.9-py3-none-any.whl size=3017173 sha256=f36fbc53d54ba3cc0439ef04f4607233803435989a5e123e6e60d330e75b3cb1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1j3slszd/wheels/2d/79/97/7209650ef73114e0fe0603480da012ad3afacb9cae6b8acd9a
# Successfully built yt-dlp
# Installing collected packages: yt-dlp
#   Attempting uninstall: yt-dlp
#     Found existing installation: yt-dlp 2025.6.9
#     Uninstalling yt-dlp-2025.6.9:
#       Successfully uninstalled yt-dlp-2025.6.9
# Successfully installed yt-dlp-2025.6.9
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from soundfile) (2.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: browser-cookie3 in /usr/local/lib/python3.11/dist-packages (0.20.1)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.11/dist-packages (from browser-cookie3) (4.4.4)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.11/dist-packages (from browser-cookie3) (3.23.0)
# Requirement already satisfied: jeepney in /usr/local/lib/python3.11/dist-packages (from browser-cookie3) (0.9.0)
# No se pueden descargar cookies desde firefox. Intentando Chrome...
# No se pueden descargar cookies desde Chrome. Por favor asegúrate de estar logueado en Youtube desde tu navegador.

# %%
import subprocess
import os

#crear carpeta con resultados
try:
  os.mkdir('results')
except:
  print("Carpeta results ya existe")

#recorrer excel con videos
N, P = X.shape
Ns = N * 5 #cantidad de segmentos por cancion

for n in range(N):
    print(f"video {n+1} de {N}")
    print(f"link: {X.loc[n,'link']}\n")
    print(f"band: {X.loc[n,'band']}\n")
    print(f"type: {X.loc[n,'type']}\n")
    #ruta video n-th
    name_ = 'results/'+X.loc[n,'band']+"_"+str(n)+"_"+str(X.loc[n,'type_num']) # #video+nombre+tipo de genero musical
    #descargar mp3 desde youtube
    try: # Added try block to catch download errors
        download_ytvid_as_mp3(X.loc[n,'link'],name_)
        #convertir a .wav
        subprocess.call(['ffmpeg','-y', '-i', name_+'.mp3',
                       name_+'.wav'])
    except youtube_dl.utils.DownloadError as e: # Catch the specific DownloadError
        print(f"Skipping video {X.loc[n,'link']} due to download error: {e}") # Print a message and skip
# Out:
# video 1 de 16
# link: https://youtu.be/DXiXPhvYuNU?t=13
#
# band: romeo santos
#
# type: bachata
#
# [youtube] Extracting URL: https://youtu.be/DXiXPhvYuNU?t=13
# [youtube] DXiXPhvYuNU: Downloading webpage
# [youtube] DXiXPhvYuNU: Downloading tv client config
# [youtube] DXiXPhvYuNU: Downloading player 94f771d8-main
# [youtube] DXiXPhvYuNU: Downloading tv player API JSON
# [youtube] DXiXPhvYuNU: Downloading ios player API JSON
# [youtube] DXiXPhvYuNU: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DXiXPhvYuNU
# [youtube] DXiXPhvYuNU: Downloading webpage
# [youtube] DXiXPhvYuNU: Downloading tv client config
# [youtube] DXiXPhvYuNU: Downloading tv player API JSON
# [youtube] DXiXPhvYuNU: Downloading ios player API JSON
# [youtube] DXiXPhvYuNU: Downloading m3u8 information
# [info] DXiXPhvYuNU: Downloading 1 format(s): 251
# [download] Destination: results/romeo santos_0_1.mp3
# [download] 100% of    4.55MiB in 00:00:00 at 14.50MiB/s
# Error descargando https://youtu.be/DXiXPhvYuNU?t=13: name 'filename' is not defined
# video 2 de 16
# link: https://youtu.be/0XCot42qTvA?t=23
#
# band: aventura
#
# type: bachata
#
# [youtube] Extracting URL: https://youtu.be/0XCot42qTvA?t=23
# [youtube] 0XCot42qTvA: Downloading webpage
# [youtube] 0XCot42qTvA: Downloading tv client config
# [youtube] 0XCot42qTvA: Downloading tv player API JSON
# [youtube] 0XCot42qTvA: Downloading ios player API JSON
# [youtube] 0XCot42qTvA: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0XCot42qTvA
# [youtube] 0XCot42qTvA: Downloading webpage
# [youtube] 0XCot42qTvA: Downloading tv client config
# [youtube] 0XCot42qTvA: Downloading tv player API JSON
# [youtube] 0XCot42qTvA: Downloading ios player API JSON
# [youtube] 0XCot42qTvA: Downloading m3u8 information
# [info] 0XCot42qTvA: Downloading 1 format(s): 251
# [download] Destination: results/aventura_1_1.mp3
# [download] 100% of    3.12MiB in 00:00:00 at 17.35MiB/s
# Error descargando https://youtu.be/0XCot42qTvA?t=23: name 'filename' is not defined
# video 3 de 16
# link: https://youtu.be/mhHqonzsuoA?t=4
#
# band: romeo santos
#
# type: bachata
#
# [youtube] Extracting URL: https://youtu.be/mhHqonzsuoA?t=4
# [youtube] mhHqonzsuoA: Downloading webpage
# [youtube] mhHqonzsuoA: Downloading tv client config
# [youtube] mhHqonzsuoA: Downloading tv player API JSON
# [youtube] mhHqonzsuoA: Downloading ios player API JSON
# [youtube] mhHqonzsuoA: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mhHqonzsuoA
# [youtube] mhHqonzsuoA: Downloading webpage
# [youtube] mhHqonzsuoA: Downloading tv client config
# [youtube] mhHqonzsuoA: Downloading tv player API JSON
# [youtube] mhHqonzsuoA: Downloading ios player API JSON
# [youtube] mhHqonzsuoA: Downloading m3u8 information
# [info] mhHqonzsuoA: Downloading 1 format(s): 251
# [download] Destination: results/romeo santos_2_1.mp3
# [download] 100% of    3.99MiB in 00:00:00 at 26.42MiB/s
# Error descargando https://youtu.be/mhHqonzsuoA?t=4: name 'filename' is not defined
# video 4 de 16
# link: https://youtu.be/ABjGqQgXRBo?t=3
#
# band: romeo santos
#
# type: bachata
#
# [youtube] Extracting URL: https://youtu.be/ABjGqQgXRBo?t=3
# [youtube] ABjGqQgXRBo: Downloading webpage
# [youtube] ABjGqQgXRBo: Downloading tv client config
# [youtube] ABjGqQgXRBo: Downloading tv player API JSON
# [youtube] ABjGqQgXRBo: Downloading ios player API JSON
# [youtube] ABjGqQgXRBo: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ABjGqQgXRBo
# [youtube] ABjGqQgXRBo: Downloading webpage
# [youtube] ABjGqQgXRBo: Downloading tv client config
# [youtube] ABjGqQgXRBo: Downloading tv player API JSON
# [youtube] ABjGqQgXRBo: Downloading ios player API JSON
# [youtube] ABjGqQgXRBo: Downloading m3u8 information
# [info] ABjGqQgXRBo: Downloading 1 format(s): 251
# [download] Destination: results/romeo santos_3_1.mp3
# [download] 100% of    4.06MiB in 00:00:00 at 8.59MiB/s
# Error descargando https://youtu.be/ABjGqQgXRBo?t=3: name 'filename' is not defined
# video 5 de 16
# link: https://youtu.be/2p_eRTj5s5M?t=25
#
# band: romeo santos
#
# type: bachata
#
# [youtube] Extracting URL: https://youtu.be/2p_eRTj5s5M?t=25
# [youtube] 2p_eRTj5s5M: Downloading webpage
# [youtube] 2p_eRTj5s5M: Downloading tv client config
# [youtube] 2p_eRTj5s5M: Downloading tv player API JSON
# [youtube] 2p_eRTj5s5M: Downloading ios player API JSON
# [youtube] 2p_eRTj5s5M: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2p_eRTj5s5M
# [youtube] 2p_eRTj5s5M: Downloading webpage
# [youtube] 2p_eRTj5s5M: Downloading tv client config
# [youtube] 2p_eRTj5s5M: Downloading tv player API JSON
# [youtube] 2p_eRTj5s5M: Downloading ios player API JSON
# [youtube] 2p_eRTj5s5M: Downloading m3u8 information
# [info] 2p_eRTj5s5M: Downloading 1 format(s): 251
# [download] Destination: results/romeo santos_4_1.mp3
# [download] 100% of    3.95MiB in 00:00:00 at 13.82MiB/s
# Error descargando https://youtu.be/2p_eRTj5s5M?t=25: name 'filename' is not defined
# video 6 de 16
# link: https://youtu.be/RjMWh1vve6E?t=2
#
# band: romeo santos
#
# type: bachata
#
# [youtube] Extracting URL: https://youtu.be/RjMWh1vve6E?t=2
# [youtube] RjMWh1vve6E: Downloading webpage
# [youtube] RjMWh1vve6E: Downloading tv client config
# [youtube] RjMWh1vve6E: Downloading tv player API JSON
# [youtube] RjMWh1vve6E: Downloading ios player API JSON
# [youtube] RjMWh1vve6E: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RjMWh1vve6E
# [youtube] RjMWh1vve6E: Downloading webpage
# [youtube] RjMWh1vve6E: Downloading tv client config
# [youtube] RjMWh1vve6E: Downloading tv player API JSON
# [youtube] RjMWh1vve6E: Downloading ios player API JSON
# [youtube] RjMWh1vve6E: Downloading m3u8 information
# [info] RjMWh1vve6E: Downloading 1 format(s): 251
# [download] Destination: results/romeo santos_5_1.mp3
# [download] 100% of    4.57MiB in 00:00:00 at 28.52MiB/s
# Error descargando https://youtu.be/RjMWh1vve6E?t=2: name 'filename' is not defined
# video 7 de 16
# link: https://youtu.be/4B7OGEy3Zgc?t=4
#
# band: royce
#
# type: bachata
#
# [youtube] Extracting URL: https://youtu.be/4B7OGEy3Zgc?t=4
# [youtube] 4B7OGEy3Zgc: Downloading webpage
# [youtube] 4B7OGEy3Zgc: Downloading tv client config
# [youtube] 4B7OGEy3Zgc: Downloading tv player API JSON
# [youtube] 4B7OGEy3Zgc: Downloading ios player API JSON
# [youtube] 4B7OGEy3Zgc: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4B7OGEy3Zgc
# [youtube] 4B7OGEy3Zgc: Downloading webpage
# [youtube] 4B7OGEy3Zgc: Downloading tv client config
# [youtube] 4B7OGEy3Zgc: Downloading tv player API JSON
# [youtube] 4B7OGEy3Zgc: Downloading ios player API JSON
# [youtube] 4B7OGEy3Zgc: Downloading m3u8 information
# [info] 4B7OGEy3Zgc: Downloading 1 format(s): 251
# [download] Destination: results/royce_6_1.mp3
# [download] 100% of    3.78MiB in 00:00:00 at 26.33MiB/s
# Error descargando https://youtu.be/4B7OGEy3Zgc?t=4: name 'filename' is not defined
# video 8 de 16
# link: https://youtu.be/8x7adVOw9G8?t=2
#
# band: romeo santos
#
# type: bachata
#
# [youtube] Extracting URL: https://youtu.be/8x7adVOw9G8?t=2
# [youtube] 8x7adVOw9G8: Downloading webpage
# [youtube] 8x7adVOw9G8: Downloading tv client config
# [youtube] 8x7adVOw9G8: Downloading tv player API JSON
# [youtube] 8x7adVOw9G8: Downloading ios player API JSON
# [youtube] 8x7adVOw9G8: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8x7adVOw9G8
# [youtube] 8x7adVOw9G8: Downloading webpage
# [youtube] 8x7adVOw9G8: Downloading tv client config
# [youtube] 8x7adVOw9G8: Downloading tv player API JSON
# [youtube] 8x7adVOw9G8: Downloading ios player API JSON
# [youtube] 8x7adVOw9G8: Downloading m3u8 information
# [info] 8x7adVOw9G8: Downloading 1 format(s): 251
# [download] Destination: results/romeo santos_7_1.mp3
# [download] 100% of    5.22MiB in 00:00:00 at 35.26MiB/s
# Error descargando https://youtu.be/8x7adVOw9G8?t=2: name 'filename' is not defined
# video 9 de 16
# link: https://youtu.be/dZYJ1yQlsY8?t=2
#
# band: david pabon
#
# type: salsa
#
# [youtube] Extracting URL: https://youtu.be/dZYJ1yQlsY8?t=2
# [youtube] dZYJ1yQlsY8: Downloading webpage
# [youtube] dZYJ1yQlsY8: Downloading tv client config
# [youtube] dZYJ1yQlsY8: Downloading tv player API JSON
# [youtube] dZYJ1yQlsY8: Downloading ios player API JSON
# [youtube] dZYJ1yQlsY8: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dZYJ1yQlsY8
# [youtube] dZYJ1yQlsY8: Downloading webpage
# [youtube] dZYJ1yQlsY8: Downloading tv client config
# [youtube] dZYJ1yQlsY8: Downloading tv player API JSON
# [youtube] dZYJ1yQlsY8: Downloading ios player API JSON
# [youtube] dZYJ1yQlsY8: Downloading m3u8 information
# [info] dZYJ1yQlsY8: Downloading 1 format(s): 251
# [download] Destination: results/david pabon_8_2.mp3
# [download] 100% of    5.87MiB in 00:00:00 at 20.32MiB/s
# Error descargando https://youtu.be/dZYJ1yQlsY8?t=2: name 'filename' is not defined
# video 10 de 16
# link: https://youtu.be/dH7bTCsNlNo?t=2
#
# band: jerry rivera
#
# type: salsa
#
# [youtube] Extracting URL: https://youtu.be/dH7bTCsNlNo?t=2
# [youtube] dH7bTCsNlNo: Downloading webpage
# [youtube] dH7bTCsNlNo: Downloading tv client config
# [youtube] dH7bTCsNlNo: Downloading tv player API JSON
# [youtube] dH7bTCsNlNo: Downloading ios player API JSON
# [youtube] dH7bTCsNlNo: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dH7bTCsNlNo
# [youtube] dH7bTCsNlNo: Downloading webpage
# [youtube] dH7bTCsNlNo: Downloading tv client config
# [youtube] dH7bTCsNlNo: Downloading tv player API JSON
# [youtube] dH7bTCsNlNo: Downloading ios player API JSON
# [youtube] dH7bTCsNlNo: Downloading m3u8 information
# [info] dH7bTCsNlNo: Downloading 1 format(s): 251
# [download] Destination: results/jerry rivera _9_2.mp3
# [download] 100% of    4.80MiB in 00:00:00 at 18.39MiB/s
# Error descargando https://youtu.be/dH7bTCsNlNo?t=2: name 'filename' is not defined
# video 11 de 16
# link: https://youtu.be/T63FtnrUDEo?t=3
#
# band: maelo ruiz
#
# type: salsa
#
# [youtube] Extracting URL: https://youtu.be/T63FtnrUDEo?t=3
# [youtube] T63FtnrUDEo: Downloading webpage
# [youtube] T63FtnrUDEo: Downloading tv client config
# [youtube] T63FtnrUDEo: Downloading tv player API JSON
# [youtube] T63FtnrUDEo: Downloading ios player API JSON
# [youtube] T63FtnrUDEo: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=T63FtnrUDEo
# [youtube] T63FtnrUDEo: Downloading webpage
# [youtube] T63FtnrUDEo: Downloading tv client config
# [youtube] T63FtnrUDEo: Downloading tv player API JSON
# [youtube] T63FtnrUDEo: Downloading ios player API JSON
# [youtube] T63FtnrUDEo: Downloading m3u8 information
# [info] T63FtnrUDEo: Downloading 1 format(s): 251
# [download] Destination: results/maelo ruiz _10_2.mp3
# [download] 100% of    5.17MiB in 00:00:00 at 18.01MiB/s
# Error descargando https://youtu.be/T63FtnrUDEo?t=3: name 'filename' is not defined
# video 12 de 16
# link: https://youtu.be/-g-3ptRfFP4?t=4
#
# band: grupo niche
#
# type: salsa
#
# [youtube] Extracting URL: https://youtu.be/-g-3ptRfFP4?t=4
# [youtube] -g-3ptRfFP4: Downloading webpage
# [youtube] -g-3ptRfFP4: Downloading tv client config
# [youtube] -g-3ptRfFP4: Downloading tv player API JSON
# [youtube] -g-3ptRfFP4: Downloading ios player API JSON
# [youtube] -g-3ptRfFP4: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-g-3ptRfFP4
# [youtube] -g-3ptRfFP4: Downloading webpage
# [youtube] -g-3ptRfFP4: Downloading tv client config
# [youtube] -g-3ptRfFP4: Downloading tv player API JSON
# [youtube] -g-3ptRfFP4: Downloading ios player API JSON
# [youtube] -g-3ptRfFP4: Downloading m3u8 information
# [info] -g-3ptRfFP4: Downloading 1 format(s): 251
# [download] Destination: results/grupo niche _11_2.mp3
# [download] 100% of    5.75MiB in 00:00:00 at 11.37MiB/s
# Error descargando https://youtu.be/-g-3ptRfFP4?t=4: name 'filename' is not defined
# video 13 de 16
# link: https://youtu.be/knlWR9mhkBs?t=11
#
# band: roberto roena
#
# type: salsa
#
# [youtube] Extracting URL: https://youtu.be/knlWR9mhkBs?t=11
# [youtube] knlWR9mhkBs: Downloading webpage
# [youtube] knlWR9mhkBs: Downloading tv client config
# [youtube] knlWR9mhkBs: Downloading tv player API JSON
# [youtube] knlWR9mhkBs: Downloading ios player API JSON
# [youtube] knlWR9mhkBs: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=knlWR9mhkBs
# [youtube] knlWR9mhkBs: Downloading webpage
# [youtube] knlWR9mhkBs: Downloading tv client config
# [youtube] knlWR9mhkBs: Downloading tv player API JSON
# [youtube] knlWR9mhkBs: Downloading ios player API JSON
# [youtube] knlWR9mhkBs: Downloading m3u8 information
# [info] knlWR9mhkBs: Downloading 1 format(s): 251-1
# [download] Destination: results/roberto roena _12_2.mp3
# [download] 100% of    5.97MiB in 00:00:00 at 8.84MiB/s
# Error descargando https://youtu.be/knlWR9mhkBs?t=11: name 'filename' is not defined
# video 14 de 16
# link: https://youtu.be/dMmPQ_Wi_Hs?t=3
#
# band: polo montanez
#
# type: salsa
#
# [youtube] Extracting URL: https://youtu.be/dMmPQ_Wi_Hs?t=3
# [youtube] dMmPQ_Wi_Hs: Downloading webpage
# [youtube] dMmPQ_Wi_Hs: Downloading tv client config
# [youtube] dMmPQ_Wi_Hs: Downloading tv player API JSON
# [youtube] dMmPQ_Wi_Hs: Downloading ios player API JSON
# [youtube] dMmPQ_Wi_Hs: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dMmPQ_Wi_Hs
# [youtube] dMmPQ_Wi_Hs: Downloading webpage
# [youtube] dMmPQ_Wi_Hs: Downloading tv client config
# [youtube] dMmPQ_Wi_Hs: Downloading tv player API JSON
# [youtube] dMmPQ_Wi_Hs: Downloading ios player API JSON
# [youtube] dMmPQ_Wi_Hs: Downloading m3u8 information
# [info] dMmPQ_Wi_Hs: Downloading 1 format(s): 251
# [download] Destination: results/polo montanez _13_2.mp3
# [download] 100% of    4.03MiB in 00:00:00 at 26.83MiB/s
# Error descargando https://youtu.be/dMmPQ_Wi_Hs?t=3: name 'filename' is not defined
# video 15 de 16
# link: https://youtu.be/X4jDz0A1Fc0?t=4
#
# band: marc anthony
#
# type: salsa
#
# [youtube] Extracting URL: https://youtu.be/X4jDz0A1Fc0?t=4
# [youtube] X4jDz0A1Fc0: Downloading webpage
# [youtube] X4jDz0A1Fc0: Downloading tv client config
# [youtube] X4jDz0A1Fc0: Downloading tv player API JSON
# [youtube] X4jDz0A1Fc0: Downloading ios player API JSON
# [youtube] X4jDz0A1Fc0: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=X4jDz0A1Fc0
# [youtube] X4jDz0A1Fc0: Downloading webpage
# [youtube] X4jDz0A1Fc0: Downloading tv client config
# [youtube] X4jDz0A1Fc0: Downloading tv player API JSON
# [youtube] X4jDz0A1Fc0: Downloading ios player API JSON
# [youtube] X4jDz0A1Fc0: Downloading m3u8 information
# [info] X4jDz0A1Fc0: Downloading 1 format(s): 251
# [download] Destination: results/marc anthony _14_2.mp3
# [download] 100% of    5.31MiB in 00:00:00 at 24.88MiB/s
# Error descargando https://youtu.be/X4jDz0A1Fc0?t=4: name 'filename' is not defined
# video 16 de 16
# link: https://youtu.be/Jca2-CCcVXk?t=4
#
# band: jerry rivera
#
# type: salsa
#
# [youtube] Extracting URL: https://youtu.be/Jca2-CCcVXk?t=4
# [youtube] Jca2-CCcVXk: Downloading webpage
# [youtube] Jca2-CCcVXk: Downloading tv client config
# [youtube] Jca2-CCcVXk: Downloading tv player API JSON
# [youtube] Jca2-CCcVXk: Downloading ios player API JSON
# [youtube] Jca2-CCcVXk: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Jca2-CCcVXk
# [youtube] Jca2-CCcVXk: Downloading webpage
# [youtube] Jca2-CCcVXk: Downloading tv client config
# [youtube] Jca2-CCcVXk: Downloading tv player API JSON
# [youtube] Jca2-CCcVXk: Downloading ios player API JSON
# [youtube] Jca2-CCcVXk: Downloading m3u8 information
# [info] Jca2-CCcVXk: Downloading 1 format(s): 251
# [download] Destination: results/jerry rivera _15_2.mp3
# [download] 100% of    5.45MiB in 00:00:00 at 34.53MiB/s
# Error descargando https://youtu.be/Jca2-CCcVXk?t=4: name 'filename' is not defined

# %%
#cargar .wavs y partir audios
#lista archivos .wav
path = 'results/'
wav_files = [f for f in os.listdir(path) if f.endswith('.wav')]
wav_files
# Out:
# ['romeo santos_2_1.wav',
#  'romeo santos_4_1.wav',
#  'romeo santos_5_1.wav',
#  'jerry rivera _9_2.wav',
#  'romeo santos_0_1.wav',
#  'grupo niche _11_2.wav',
#  'romeo santos_7_1.wav',
#  'david pabon_8_2.wav',
#  'jerry rivera _15_2.wav',
#  'maelo ruiz _10_2.wav',
#  'aventura_1_1.wav',
#  'romeo santos_3_1.wav',
#  'marc anthony _14_2.wav',
#  'royce_6_1.wav',
#  'roberto roena _12_2.wav',
#  'polo montanez _13_2.wav']

# %%
import soundfile as sf # para instalar pip install soundfile
from scipy.signal import resample_poly
import numpy as np
import os

#leer archivos y crear np.array audios
fs = 48000
tl = np.array([30,40,50,60,70,80]) #puntos lectura
ts = 5 #t segmento
# The total number of samples for each segment at the target fs
segment_length_fs = int(ts * fs)
Ns = len(wav_files)*len(tl) #cantidad segmentos
# x_t should be initialized with the shape corresponding to the target fs
x_t = np.zeros((Ns, segment_length_fs, 2)) #Ns segmentos, cantidad de muestras, 2 canales (stereo)
label = np.zeros((Ns,1)) #vector tipo de genero
type_c = X['type'].unique()
name_c = []
#leer archivos wav
i = 0
for name in wav_files:#lectura audio .wav
    x, fs_i = sf.read(path+name)
    # Ensure x is at least 2D (for stereo)

    if x.ndim == 1:
        x = np.expand_dims(x, axis=1) # Add a channel dimension if mono
    if x.shape[1] == 1: # If still mono after expand_dims
        x = np.repeat(x, 2, axis=1) # Convert mono to stereo by repeating the channel

    # Check if the audio file has enough data for the requested segments
    if len(x) < int(fs_i * (tl[-1] + ts)):
        print(f"Warning: File {name} is too short for all requested segments. Skipping some segments.")
        valid_tl = tl[tl + ts <= len(x)/fs_i]
    else:
        valid_tl = tl

    for ti in valid_tl: #segmentos de tiempo
        print(name,'x',x.shape,'fs actual:',fs_i)

        # Slice based on the original sampling rate fs_i
        start_sample = int(fs_i * ti)
        end_sample = int(fs_i * (ti + ts))
        xc = x[start_sample:end_sample, :]

        # Check if the sliced segment has enough data for resampling
        # This can happen if the calculated end_sample exceeds the actual audio length
        if xc.shape[0] < int(ts * fs_i):
            print(f"Warning: Segment from {ti}s to {ti+ts}s in {name} is shorter than expected. Skipping.")
            continue # Skip this segment

        if fs_i != fs:
            # Resample using resample_poly
            # The output length of resample_poly is len(xc) * up / down
            # We want the resampled length to be exactly segment_length_fs
            # So we need to calculate up and down such that len(xc) * up / down = segment_length_fs
            # Or simply use the desired number of samples directly if supported by resample_poly
            # resample_poly can take 'nyq' or 'kaiser_beta' arguments for filter design,
            # but for simple resampling to a target number of points, a direct approach is needed.
            # A simpler resample function might be better, or calculate up/down differently.

            # Let's use a method that targets the desired number of samples directly.
            # scipy.signal.resample can do this, but it uses FFT and might not be ideal.
            # Let's adjust the resampling calculation with resample_poly to ensure the correct output size.
            # Target output size is segment_length_fs.
            # Current size is xc.shape[0].
            # We want xc.shape[0] * (up / down) = segment_length_fs
            # Let's find up and down that approximate fs/fs_i
            # A more robust way is to use a library that handles resampling to a specific length.
            # For now, let's ensure the resampled array is truncated or padded if necessary,
            # although it's better to get the resampling right.

            # A common approach for arbitrary resampling is
            # import librosa
            # xc_resampled = librosa.resample(xc, orig_sr=fs_i, target_sr=fs)
            # However, this outputs a 1D array for mono. Need to handle stereo.

            # Let's stick with resample_poly but ensure the output is the correct size.
            # If resampling makes it slightly longer or shorter, we'll handle it.
            gcd_val = np.gcd(fs, fs_i)
            up_val = fs // gcd_val
            down_val = fs_i // gcd_val

            # Resample each channel separately
            xc_resampled_ch1 = resample_poly(xc[:, 0], up=up_val, down=down_val)
            xc_resampled_ch2 = resample_poly(xc[:, 1], up=up_val, down=down_val)

            # Combine channels
            xc_resampled = np.stack((xc_resampled_ch1, xc_resampled_ch2), axis=-1)

            # Ensure the resampled segment has the target length (segment_length_fs)
            if xc_resampled.shape[0] > segment_length_fs:
                xc_resampled = xc_resampled[:segment_length_fs, :]
            elif xc_resampled.shape[0] < segment_length_fs:
                # Pad with zeros if shorter
                padding = np.zeros((segment_length_fs - xc_resampled.shape[0], 2))
                xc_resampled = np.vstack((xc_resampled, padding))

            xc = xc_resampled # Use the resampled array
            print(f"Resampled to shape: {xc.shape}")

        # Now xc should have the shape (segment_length_fs, 2) which is (240000, 2)
        if xc.shape[0] != segment_length_fs:
             print(f"Error: Resampled segment has incorrect length {xc.shape[0]}. Expected {segment_length_fs}. Skipping.")
             continue # Skip this segment if resampling failed to produce correct length


        x_t[i] = xc
        # The label indexing seems to assume the order of wav_files matches the order in X
        # and the type_num is the last digit before '.wav' and is 1 or 2.
        # This might be fragile. Consider using the 'type_num' column from X directly
        # based on the filename or a mapping.
        # For now, sticking to the original logic for the label.
        try:
             # Extract type_num from the filename
             parts = name.split('_')
             type_num_str = parts[-1].split('.')[0]
             label[i] = int(type_num_str)
        except (IndexError, ValueError):
             print(f"Warning: Could not extract type_num from filename {name}. Setting label to 0.")
             label[i] = 0 # Assign a default or error label

        # The name_c logic also seems to assume the filename format.
        # Sticking to original logic.
        name_c += [name[:-4]] # Remove '.wav' from the end


        print(f"{i} lectura: {name}; segundo {ti}:{ti+ts}; tipo música: {type_c[int(label[i])-1]}")
        i+=1

# After the loop, if some segments were skipped, the actual number of populated segments in x_t and label
# might be less than Ns. We should truncate these arrays to the actual number of populated segments.
# Ns was calculated based on the initial assumption of processing all segments.
# Let's re-calculate the effective Ns (number of processed segments).
effective_Ns = i
x_t = x_t[:effective_Ns]
label = label[:effective_Ns]
name_c = name_c[:effective_Ns]

x_t.shape
# Out:
# romeo santos_2_1.wav x (11289914, 2) fs actual: 48000
# 0 lectura: romeo santos_2_1.wav; segundo 30:35; tipo música: bachata
# romeo santos_2_1.wav x (11289914, 2) fs actual: 48000
# 1 lectura: romeo santos_2_1.wav; segundo 40:45; tipo música: bachata
# romeo santos_2_1.wav x (11289914, 2) fs actual: 48000
# 2 lectura: romeo santos_2_1.wav; segundo 50:55; tipo música: bachata
# romeo santos_2_1.wav x (11289914, 2) fs actual: 48000
# 3 lectura: romeo santos_2_1.wav; segundo 60:65; tipo música: bachata
# romeo santos_2_1.wav x (11289914, 2) fs actual: 48000
# 4 lectura: romeo santos_2_1.wav; segundo 70:75; tipo música: bachata
# romeo santos_2_1.wav x (11289914, 2) fs actual: 48000
# 5 lectura: romeo santos_2_1.wav; segundo 80:85; tipo música: bachata
# romeo santos_4_1.wav x (11642114, 2) fs actual: 48000
# 6 lectura: romeo santos_4_1.wav; segundo 30:35; tipo música: bachata
# romeo santos_4_1.wav x (11642114, 2) fs actual: 48000
# 7 lectura: romeo santos_4_1.wav; segundo 40:45; tipo música: bachata
# romeo santos_4_1.wav x (11642114, 2) fs actual: 48000
# 8 lectura: romeo santos_4_1.wav; segundo 50:55; tipo música: bachata
# romeo santos_4_1.wav x (11642114, 2) fs actual: 48000
# 9 lectura: romeo santos_4_1.wav; segundo 60:65; tipo música: bachata
# romeo santos_4_1.wav x (11642114, 2) fs actual: 48000
# 10 lectura: romeo santos_4_1.wav; segundo 70:75; tipo música: bachata
# romeo santos_4_1.wav x (11642114, 2) fs actual: 48000
# <ipython-input-7-2722154239>:126: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(f"{i} lectura: {name}; segundo {ti}:{ti+ts}; tipo música: {type_c[int(label[i])-1]}")
# 11 lectura: romeo santos_4_1.wav; segundo 80:85; tipo música: bachata
# romeo santos_5_1.wav x (12928000, 2) fs actual: 48000
# 12 lectura: romeo santos_5_1.wav; segundo 30:35; tipo música: bachata
# romeo santos_5_1.wav x (12928000, 2) fs actual: 48000
# 13 lectura: romeo santos_5_1.wav; segundo 40:45; tipo música: bachata
# romeo santos_5_1.wav x (12928000, 2) fs actual: 48000
# 14 lectura: romeo santos_5_1.wav; segundo 50:55; tipo música: bachata
# romeo santos_5_1.wav x (12928000, 2) fs actual: 48000
# 15 lectura: romeo santos_5_1.wav; segundo 60:65; tipo música: bachata
# romeo santos_5_1.wav x (12928000, 2) fs actual: 48000
# 16 lectura: romeo santos_5_1.wav; segundo 70:75; tipo música: bachata
# romeo santos_5_1.wav x (12928000, 2) fs actual: 48000
# 17 lectura: romeo santos_5_1.wav; segundo 80:85; tipo música: bachata
# jerry rivera _9_2.wav x (13413704, 2) fs actual: 48000
# 18 lectura: jerry rivera _9_2.wav; segundo 30:35; tipo música: salsa
# jerry rivera _9_2.wav x (13413704, 2) fs actual: 48000
# 19 lectura: jerry rivera _9_2.wav; segundo 40:45; tipo música: salsa
# jerry rivera _9_2.wav x (13413704, 2) fs actual: 48000
# 20 lectura: jerry rivera _9_2.wav; segundo 50:55; tipo música: salsa
# jerry rivera _9_2.wav x (13413704, 2) fs actual: 48000
# 21 lectura: jerry rivera _9_2.wav; segundo 60:65; tipo música: salsa
# jerry rivera _9_2.wav x (13413704, 2) fs actual: 48000
# 22 lectura: jerry rivera _9_2.wav; segundo 70:75; tipo música: salsa
# jerry rivera _9_2.wav x (13413704, 2) fs actual: 48000
# 23 lectura: jerry rivera _9_2.wav; segundo 80:85; tipo música: salsa
# romeo santos_0_1.wav x (13177975, 2) fs actual: 48000
# 24 lectura: romeo santos_0_1.wav; segundo 30:35; tipo música: bachata
# romeo santos_0_1.wav x (13177975, 2) fs actual: 48000
# 25 lectura: romeo santos_0_1.wav; segundo 40:45; tipo música: bachata
# romeo santos_0_1.wav x (13177975, 2) fs actual: 48000
# 26 lectura: romeo santos_0_1.wav; segundo 50:55; tipo música: bachata
# romeo santos_0_1.wav x (13177975, 2) fs actual: 48000
# 27 lectura: romeo santos_0_1.wav; segundo 60:65; tipo música: bachata
# romeo santos_0_1.wav x (13177975, 2) fs actual: 48000
# 28 lectura: romeo santos_0_1.wav; segundo 70:75; tipo música: bachata
# romeo santos_0_1.wav x (13177975, 2) fs actual: 48000
# 29 lectura: romeo santos_0_1.wav; segundo 80:85; tipo música: bachata
# grupo niche _11_2.wav x (15907527, 2) fs actual: 48000
# 30 lectura: grupo niche _11_2.wav; segundo 30:35; tipo música: salsa
# grupo niche _11_2.wav x (15907527, 2) fs actual: 48000
# 31 lectura: grupo niche _11_2.wav; segundo 40:45; tipo música: salsa
# grupo niche _11_2.wav x (15907527, 2) fs actual: 48000
# 32 lectura: grupo niche _11_2.wav; segundo 50:55; tipo música: salsa
# grupo niche _11_2.wav x (15907527, 2) fs actual: 48000
# 33 lectura: grupo niche _11_2.wav; segundo 60:65; tipo música: salsa
# grupo niche _11_2.wav x (15907527, 2) fs actual: 48000
# 34 lectura: grupo niche _11_2.wav; segundo 70:75; tipo música: salsa
# grupo niche _11_2.wav x (15907527, 2) fs actual: 48000
# 35 lectura: grupo niche _11_2.wav; segundo 80:85; tipo música: salsa
# romeo santos_7_1.wav x (14605166, 2) fs actual: 48000
# 36 lectura: romeo santos_7_1.wav; segundo 30:35; tipo música: bachata
# romeo santos_7_1.wav x (14605166, 2) fs actual: 48000
# 37 lectura: romeo santos_7_1.wav; segundo 40:45; tipo música: bachata
# romeo santos_7_1.wav x (14605166, 2) fs actual: 48000
# 38 lectura: romeo santos_7_1.wav; segundo 50:55; tipo música: bachata
# romeo santos_7_1.wav x (14605166, 2) fs actual: 48000
# 39 lectura: romeo santos_7_1.wav; segundo 60:65; tipo música: bachata
# romeo santos_7_1.wav x (14605166, 2) fs actual: 48000
# 40 lectura: romeo santos_7_1.wav; segundo 70:75; tipo música: bachata
# romeo santos_7_1.wav x (14605166, 2) fs actual: 48000
# 41 lectura: romeo santos_7_1.wav; segundo 80:85; tipo música: bachata
# david pabon_8_2.wav x (15646163, 2) fs actual: 48000
# 42 lectura: david pabon_8_2.wav; segundo 30:35; tipo música: salsa
# david pabon_8_2.wav x (15646163, 2) fs actual: 48000
# 43 lectura: david pabon_8_2.wav; segundo 40:45; tipo música: salsa
# david pabon_8_2.wav x (15646163, 2) fs actual: 48000
# 44 lectura: david pabon_8_2.wav; segundo 50:55; tipo música: salsa
# david pabon_8_2.wav x (15646163, 2) fs actual: 48000
# 45 lectura: david pabon_8_2.wav; segundo 60:65; tipo música: salsa
# david pabon_8_2.wav x (15646163, 2) fs actual: 48000
# 46 lectura: david pabon_8_2.wav; segundo 70:75; tipo música: salsa
# david pabon_8_2.wav x (15646163, 2) fs actual: 48000
# 47 lectura: david pabon_8_2.wav; segundo 80:85; tipo música: salsa
# jerry rivera _15_2.wav x (14681513, 2) fs actual: 48000
# 48 lectura: jerry rivera _15_2.wav; segundo 30:35; tipo música: salsa
# jerry rivera _15_2.wav x (14681513, 2) fs actual: 48000
# 49 lectura: jerry rivera _15_2.wav; segundo 40:45; tipo música: salsa
# jerry rivera _15_2.wav x (14681513, 2) fs actual: 48000
# 50 lectura: jerry rivera _15_2.wav; segundo 50:55; tipo música: salsa
# jerry rivera _15_2.wav x (14681513, 2) fs actual: 48000
# 51 lectura: jerry rivera _15_2.wav; segundo 60:65; tipo música: salsa
# jerry rivera _15_2.wav x (14681513, 2) fs actual: 48000
# 52 lectura: jerry rivera _15_2.wav; segundo 70:75; tipo música: salsa
# jerry rivera _15_2.wav x (14681513, 2) fs actual: 48000
# 53 lectura: jerry rivera _15_2.wav; segundo 80:85; tipo música: salsa
# maelo ruiz _10_2.wav x (13880146, 2) fs actual: 48000
# 54 lectura: maelo ruiz _10_2.wav; segundo 30:35; tipo música: salsa
# maelo ruiz _10_2.wav x (13880146, 2) fs actual: 48000
# 55 lectura: maelo ruiz _10_2.wav; segundo 40:45; tipo música: salsa
# maelo ruiz _10_2.wav x (13880146, 2) fs actual: 48000
# 56 lectura: maelo ruiz _10_2.wav; segundo 50:55; tipo música: salsa
# maelo ruiz _10_2.wav x (13880146, 2) fs actual: 48000
# 57 lectura: maelo ruiz _10_2.wav; segundo 60:65; tipo música: salsa
# maelo ruiz _10_2.wav x (13880146, 2) fs actual: 48000
# 58 lectura: maelo ruiz _10_2.wav; segundo 70:75; tipo música: salsa
# maelo ruiz _10_2.wav x (13880146, 2) fs actual: 48000
# 59 lectura: maelo ruiz _10_2.wav; segundo 80:85; tipo música: salsa
# aventura_1_1.wav x (11731968, 2) fs actual: 48000
# 60 lectura: aventura_1_1.wav; segundo 30:35; tipo música: bachata
# aventura_1_1.wav x (11731968, 2) fs actual: 48000
# 61 lectura: aventura_1_1.wav; segundo 40:45; tipo música: bachata
# aventura_1_1.wav x (11731968, 2) fs actual: 48000
# 62 lectura: aventura_1_1.wav; segundo 50:55; tipo música: bachata
# aventura_1_1.wav x (11731968, 2) fs actual: 48000
# 63 lectura: aventura_1_1.wav; segundo 60:65; tipo música: bachata
# aventura_1_1.wav x (11731968, 2) fs actual: 48000
# 64 lectura: aventura_1_1.wav; segundo 70:75; tipo música: bachata
# aventura_1_1.wav x (11731968, 2) fs actual: 48000
# 65 lectura: aventura_1_1.wav; segundo 80:85; tipo música: bachata
# romeo santos_3_1.wav x (11118272, 2) fs actual: 48000
# 66 lectura: romeo santos_3_1.wav; segundo 30:35; tipo música: bachata
# romeo santos_3_1.wav x (11118272, 2) fs actual: 48000
# 67 lectura: romeo santos_3_1.wav; segundo 40:45; tipo música: bachata
# romeo santos_3_1.wav x (11118272, 2) fs actual: 48000
# 68 lectura: romeo santos_3_1.wav; segundo 50:55; tipo música: bachata
# romeo santos_3_1.wav x (11118272, 2) fs actual: 48000
# 69 lectura: romeo santos_3_1.wav; segundo 60:65; tipo música: bachata
# romeo santos_3_1.wav x (11118272, 2) fs actual: 48000
# 70 lectura: romeo santos_3_1.wav; segundo 70:75; tipo música: bachata
# romeo santos_3_1.wav x (11118272, 2) fs actual: 48000
# 71 lectura: romeo santos_3_1.wav; segundo 80:85; tipo música: bachata
# marc anthony _14_2.wav x (14083553, 2) fs actual: 48000
# 72 lectura: marc anthony _14_2.wav; segundo 30:35; tipo música: salsa
# marc anthony _14_2.wav x (14083553, 2) fs actual: 48000
# 73 lectura: marc anthony _14_2.wav; segundo 40:45; tipo música: salsa
# marc anthony _14_2.wav x (14083553, 2) fs actual: 48000
# 74 lectura: marc anthony _14_2.wav; segundo 50:55; tipo música: salsa
# marc anthony _14_2.wav x (14083553, 2) fs actual: 48000
# 75 lectura: marc anthony _14_2.wav; segundo 60:65; tipo música: salsa
# marc anthony _14_2.wav x (14083553, 2) fs actual: 48000
# 76 lectura: marc anthony _14_2.wav; segundo 70:75; tipo música: salsa
# marc anthony _14_2.wav x (14083553, 2) fs actual: 48000
# 77 lectura: marc anthony _14_2.wav; segundo 80:85; tipo música: salsa
# royce_6_1.wav x (10664090, 2) fs actual: 48000
# 78 lectura: royce_6_1.wav; segundo 30:35; tipo música: bachata
# royce_6_1.wav x (10664090, 2) fs actual: 48000
# 79 lectura: royce_6_1.wav; segundo 40:45; tipo música: bachata
# royce_6_1.wav x (10664090, 2) fs actual: 48000
# 80 lectura: royce_6_1.wav; segundo 50:55; tipo música: bachata
# royce_6_1.wav x (10664090, 2) fs actual: 48000
# 81 lectura: royce_6_1.wav; segundo 60:65; tipo música: bachata
# royce_6_1.wav x (10664090, 2) fs actual: 48000
# 82 lectura: royce_6_1.wav; segundo 70:75; tipo música: bachata
# royce_6_1.wav x (10664090, 2) fs actual: 48000
# 83 lectura: royce_6_1.wav; segundo 80:85; tipo música: bachata
# roberto roena _12_2.wav x (16400162, 2) fs actual: 48000
# 84 lectura: roberto roena _12_2.wav; segundo 30:35; tipo música: salsa
# roberto roena _12_2.wav x (16400162, 2) fs actual: 48000
# 85 lectura: roberto roena _12_2.wav; segundo 40:45; tipo música: salsa
# roberto roena _12_2.wav x (16400162, 2) fs actual: 48000
# 86 lectura: roberto roena _12_2.wav; segundo 50:55; tipo música: salsa
# roberto roena _12_2.wav x (16400162, 2) fs actual: 48000
# 87 lectura: roberto roena _12_2.wav; segundo 60:65; tipo música: salsa
# roberto roena _12_2.wav x (16400162, 2) fs actual: 48000
# 88 lectura: roberto roena _12_2.wav; segundo 70:75; tipo música: salsa
# roberto roena _12_2.wav x (16400162, 2) fs actual: 48000
# 89 lectura: roberto roena _12_2.wav; segundo 80:85; tipo música: salsa
# polo montanez _13_2.wav x (12679168, 2) fs actual: 48000
# 90 lectura: polo montanez _13_2.wav; segundo 30:35; tipo música: salsa
# polo montanez _13_2.wav x (12679168, 2) fs actual: 48000
# 91 lectura: polo montanez _13_2.wav; segundo 40:45; tipo música: salsa
# polo montanez _13_2.wav x (12679168, 2) fs actual: 48000
# 92 lectura: polo montanez _13_2.wav; segundo 50:55; tipo música: salsa
# polo montanez _13_2.wav x (12679168, 2) fs actual: 48000
# 93 lectura: polo montanez _13_2.wav; segundo 60:65; tipo música: salsa
# polo montanez _13_2.wav x (12679168, 2) fs actual: 48000
# 94 lectura: polo montanez _13_2.wav; segundo 70:75; tipo música: salsa
# polo montanez _13_2.wav x (12679168, 2) fs actual: 48000
# 95 lectura: polo montanez _13_2.wav; segundo 80:85; tipo música: salsa
# (96, 240000, 2)

# %%
from IPython.display import Audio #reproducir segmento
i = 0
Audio(x_t[i].T,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#calculo de fourier
vf = np.fft.rfftfreq(x_t.shape[1],1/fs) #calculo vector de frecuencias
Xw = np.fft.rfft(x_t,axis=1).mean(axis=-1) #transformada rapida de Fourier para señal Real a lo largo del tiempo (axis=1) y se promedian los dos canales
Xw.shape
# Out:
# (96, 120001)

# %%
#grafica tiempo y fourier
plt.plot(np.arange(0,ts,1/fs),x_t.mean(axis=-1).T) #se promedian los dos canales stereo
plt.xlabel('t[s]')
plt.ylabel('x(t)')
plt.show()

# %%
plt.plot(vf,abs(Xw).T)
plt.xlabel('f[Hz]')
plt.ylabel('|X(f)|')
plt.show()

# %%
#se normalizan espectros entre 0 y 1 para evitar inconsistencias por ampliltudes máximas
from sklearn.preprocessing import MinMaxScaler
sca = MinMaxScaler()
Xw_ = sca.fit_transform(abs(Xw).T).T

plt.plot(vf,Xw_.T)
plt.xlabel('f[Hz]')
plt.ylabel('|X(f)|')
plt.show()

#en dB
plt.plot(vf,(20*np.log10(Xw_+1e-10)).T) # se suma 1e-10 para evitar discontinuidad del log
plt.xlabel('f[Hz]')
plt.ylabel('|X(f)| dB')
plt.show()

# %% [markdown]
# **Nota**:
# Generalmente el espectro se presenta en [decibeles [dB]](https://es.wikipedia.org/wiki/Decibelio)

# %% [markdown]
# ###**visualizacio de datos en 2D**

# %%
from umap import UMAP
#visualización de datos
n_neighbors = int(2*np.sqrt(Xw_.shape[0]))
sca_ = MinMaxScaler()

red_ = UMAP(n_components=2,n_neighbors=n_neighbors)
X_2D = sca_.fit_transform(red_.fit_transform(Xw_))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
#graficar separabilidad 2D
plt.scatter(X_2D[:,0],X_2D[:,1],c=label)
plt.colorbar()
plt.show()

color_ = ["b","y"]
#nombre cancion
plt.scatter(X_2D[:,0],X_2D[:,1],c=label,s=1)
for i, tex in enumerate(name_c):
    #print(f"{i} {tex}")
    plt.text(X_2D[i,0]*1.025,X_2D[i,1]*1.025, tex[:-2]+"_"+str(i), fontsize=6,color=color_[int(label[i]-1)])

plt.xlim([-0.1,1.1])
plt.ylim([-0.1,1.1])
plt.show()

# %%
#reproducir audio
i = 1
Audio(x_t[i].T,rate=fs)

# %% [markdown]
# ##**PREDICCION DEL GENERO MUSICAL SOBRE EL ESPECTRO DE FURIEL**

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# Crear una instancia del clasificador RandomForest
model = KNeighborsClassifier(n_neighbors=5)

# Realizar la validación cruzada
# Xw_ son tus características y label son tus etiquetas
# cv define el número folds para la validación cruzada
scores = cross_val_score(model, Xw_, label.ravel(), cv=5,scoring='accuracy')

# Imprimir los resultados de la validación cruzada
print("Acierto para cada Fold:", scores)
print("Acierto promedio:", scores.mean())
print("Desviación estándar del Acierto:", scores.std())

#entrenar modelo para predecir nuevas canciones
model.fit(Xw_, label.ravel())

# %%
import joblib
#guardar modelo
try:
  os.mkdir('modelo')
except:
  print("Carpeta modelo ya existe")

filename_ = 'modelo/reggaeton_vs_bachata'
model_ ={'Xw_':Xw_, 'label' : label, 'name_c' : name_c, 'vf':vf,'fs':fs, 'modelo':model,'type':X['type'].unique()}
joblib.dump(model_,filename_+".pkl")

# %%
#descargar modelo
#guardar resultados
from google.colab import files
from datetime import date, datetime
import shutil
#guardar resultados
namefile = str(datetime.now().strftime("%Y_%m_%d_%H_%M_%d"))+'modelo'
shutil.make_archive(namefile, 'zip', 'modelo')
files.download(namefile+'.zip')

#el archivo .zip puede cargarse en drive y utilizarse en otro cuaderno para detectar género musical de nuevos segmentos

# %%
#cargar modelo
my_model_loaded = joblib.load(filename_+".pkl")
my_model_loaded.keys()

# %%
#evaluar para un segmento en fft normalizado

pred_ = my_model_loaded['modelo'].predict(Xw_[0].reshape(1,-1))[0]
print('Etiqueta estimada: ',my_model_loaded['type'][int(pred_-1)])
print('Etiqueta orignal: ',my_model_loaded['type'][int(my_model_loaded['label'][0][0])-1])
